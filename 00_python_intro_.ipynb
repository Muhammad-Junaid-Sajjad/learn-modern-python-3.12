# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Junaid-Sajjad/learn-modern-python-3.12/blob/main/00_python_intro_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCTION** ✈

# %% [markdown]
# Welcome to Modern Python 3.12 with Type Hinting ( Introduction )

# %% [markdown]
# # New Section

# %%
print(" Hello World ! ")
# Out:
#  Hello World !

# %%
print(" This is Junaid From PIAIC")
# Out:
#  This is Junaid From PIAIC

# %%
print("I AM GOING TO START PIAIC AI-101 COURSES NOW ")
# Out:
# I AM GOING TO START PIAIC AI-101 COURSES NOW

# %%
str : fav_celebrity  = "Hamzah"
fav_celebrity : str = "Hamzaah"
print("fav_celebrity")
print(fav_celebrity)
# Out:
# fav_celebrity
# Hamzaah

# %%
print("Hi Junaid @ Agentic Ai Engineer ")
# Out:
# Hi Junaid @ Agentic Ai Engineer

# %%
fav_Celebrity : str = 'Shahhzeb Khan Zada'
print (fav_Celebrity)
# Out:
# Shahhzeb Khan Zada

# %%
sentence : str = "\nMy name is"
name : str = " khalid"

print(sentence)
print(name)

print(sentence+name)
# Out:
# My name is
#  khalid
#
# My name is khalid

# %%
sentence : str = "\n My name is "
name : str = "Junaid"

print(sentence+name)

print(sentence)
print(name)
# Out:
#  My name is Junaid
#
#  My name is
# Junaid
